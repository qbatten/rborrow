# %% [markdown]
# Okay, so here's some stuff.

# %%
import sys
import os
sys.path.append(os.path.abspath("/Users/quinnbatten/Documents/Programming/PyProjects/rborrow"))
from main import *

allcollect = niceify()
bor = allcollect[0]
lend = allcollect[1]
# Out:
# /Users/quinnbatten/Documents/Programming/PyProjects/rborrow/main1.json

# %%
import pprint
pprint.pprint(bor)
# Out:
# {'0megaaa': '100',
#  '100Kay': '650',
#  '12px': '300',
#  '13787': '25',
#  '25_timesthefine': None,
#  '3vtsiul': '500',
#  '6ixKen': '100',
#  '73oo73ie3': '400',
#  '99anan99': '1500',
#  'AKA_AmbulanceDriver': '22',
#  'AceMatisse': '.00',
#  'Adamdkc': None,
#  'AhmFukkinRakkin': None,
#  'Akavinceblack': '230',
#  'AlfredoSantana': '400',
#  'AllDayPeterson': '530',
#  'AllWaysKicking': '1200',
#  'AnnanWater': None,
#  'ArbyMelt': None,
#  'Ariellograms': '500',
#  'AshViolette': None,
#  'Ashkir': None,
#  'Ask-About-My-Book': '15',
#  'AstralWeekss': None,
#  'Attora': '50',
#  'Awesomeslayerg': '50',
#  'BAlice': '100',
#  'BOOMROASTED2005': '160',
#  'BananaFantana00': None,
#  'Benj97s': None,
#  'BettaLaInu': '200',
#  'BiasedBavarian': None,
#  'BigNickDigger69420': None,
#  'Binky182': None,
#  'Bloodydyce': '500',
#  'BluePeanutz': '225',
#  'BluxDaiz': '40',
#  'Brachra': '.00-400',
#  'BrehRA': None,
#  'Breslayy': None,
#  'CaptainPizza': '750',
# ...

# %%
import numpy as np
loans = []
for key, val in bor.items():
    try:
        int(val)
    except:
        pass
    else: 
        if int(val) > 0:
            loans.append(int(val))
        
loanvals = np.array(loans)
print(loanvals)
# Out:
# [ 200   50   60  260 1000  850 1400 1200  200  350  100  300   50  750
#  1500 2700   80  100   60  500  800   50  960  750  100  200   40   13
#   175 1300   30  600  100  600  200  900  600  400  100  110  100  600
#   655  650  150 1200  400  300  350  120  450   80   40  600  350  100
#    40  600  300  700  150  220   20  150  800  100  350   25  500  300
#   100 1000  400  300   50   75   50  300 1100   80  100   80  100   75
#   160  275  300  100   60   55 1000  230 1600   15   55  500   70   50
#   150  150 1500  160  500   50   50  160  250  100  150  200  650   60
#   400   60  500  200  100   25  225  500  250  250  300  300  250   40
#    65  200   15 3000  150  250  400  100  700  400  500  475  200  200
#   200   80   30  500  475  100  450  300  150  150  205  750  450 1500
#   600  300  750  275  530  350  100   55  600   60  110  350   80  600
#    25  220  115  170  500  100  500  200  100   50  700   50  325   50
# ...

# %%
loanvals.shape
# Out:
# (340,)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # set plot style

# %%
plt.hist(loanvals, bins=20)
# Out:
# (array([144.,  81.,  31.,  39.,  14.,   8.,   5.,   6.,   2.,   6.,   1.,
#           0.,   0.,   1.,   0.,   0.,   0.,   1.,   0.,   1.]),
#  array([  10. ,  159.5,  309. ,  458.5,  608. ,  757.5,  907. , 1056.5,
#         1206. , 1355.5, 1505. , 1654.5, 1804. , 1953.5, 2103. , 2252.5,
#         2402. , 2551.5, 2701. , 2850.5, 3000. ]),
#  <a list of 20 Patch objects>)
